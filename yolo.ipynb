# %%
# !pip install ultralytics supervision roboflow
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="xai3waM8J9zJBNreNjSx")
project = rf.workspace("objectdetection-dsy2y").project("ball_detection-qei8i")
version = project.version(2)
dataset = version.download("yolov11")

# %%
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics 8.3.122  Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# Setup complete  (16 CPUs, 31.1 GB RAM, 388.6/476.9 GB disk)

# %%
model = YOLO('yolo11m.pt')

# %%
model.train(data='Dataset\\ballDataset\\data.yaml', epochs=50, imgsz=640, batch=16, device=0, workers=4, project='runs/train', name='yolo11m_ball', exist_ok=True, plots=True)
# Out:
# New https://pypi.org/project/ultralytics/8.3.124 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.122  Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# ...

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'runs\\train\yolo11m_ball\\confusion_matrix.png', width=600)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\y'
# <>:3: SyntaxWarning: invalid escape sequence '\y'
# C:\Users\moham\AppData\Local\Temp\ipykernel_3768\2198642956.py:3: SyntaxWarning: invalid escape sequence '\y'
#   IPyImage(filename=f'runs\\train\yolo11m_ball\\confusion_matrix.png', width=600)

# %%
model = YOLO('runs/train/yolo11m_ball/weights/best.pt')
model.predict(source='Dataset\\ballDataset\\test\\images', conf=0.25, save=True, save_txt=True, project='runs/predict', name='yolo11m_ball_test', exist_ok=True, plots=True, device=0)
# Out:
# image 1/5 e:\CSE475\Dataset\ballDataset\test\images\image_138_jpg.rf.cbdb359f7c7612ac3c1abe9766b405b2.jpg: 640x640 1 blue ball, 1 green ball, 1 red ball, 10.8ms
# image 2/5 e:\CSE475\Dataset\ballDataset\test\images\image_143_jpg.rf.775525f3149ff8b5e1361698adf96f5e.jpg: 640x640 1 blue ball, 1 green ball, 1 red ball, 8.7ms
# image 3/5 e:\CSE475\Dataset\ballDataset\test\images\image_167_jpg.rf.08a1fffa0d2f1105bc2eac6e36c5f522.jpg: 640x640 1 blue ball, 1 green ball, 1 red ball, 9.1ms
# image 4/5 e:\CSE475\Dataset\ballDataset\test\images\image_200_jpg.rf.c49aedbcc836b3cfb7441c6d9e7dc064.jpg: 640x640 1 blue ball, 1 green ball, 1 red ball, 9.8ms
# image 5/5 e:\CSE475\Dataset\ballDataset\test\images\image_203_jpg.rf.494ec3a384999f6d95e3a32b604ec937.jpg: 640x640 1 blue ball, 1 green ball, 1 red ball, 11.7ms
# Speed: 1.7ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\predict\yolo11m_ball_test
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('./runs/predict/yolo11m_ball_test*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:3]:
	display(IPyImage(filename=img, width=600))
	print("\n")
